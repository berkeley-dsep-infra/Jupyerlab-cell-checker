# %% [markdown]
# transparent without alt tag html
#
# <img  alt="" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png" ></img>

# %% [markdown]
# transparent with alt tag html in front
#
# <img
# alt="The image shows a collection of six colorful dice with the numbers six and five visible on two of them. The dice are arranged in a way that they appear to be falling or rolling towards each other, creating a dynamic, playful scene. (This is an alt-text generated by a language model)"  src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png" ></img>

# %% [markdown]
# transparent with alt tag html in back
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png" alt="A whimsical scene featuring a bunch of colorful dice, some resting on top of each other. (This is an alt-text generated by a language model)"></img>

# %% [markdown]
# transparent with alt tag html in back
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png" alt="Four colorful dices, symbolizing luck or chance, with a reflective surface beneath them. (This is an alt-text generated by a language model)" width="30"></img>

# %% [markdown]
# transparent with alt tag markdown
#
# ![The image displays four die with various colored pips (dots). These dice are vibrant in colors like red, green, blue, and yellow. They are arranged casually around each other, showcasing their randomness and the joy of a fun dice game. (This is an alt-text generated by a language model)](https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png)

# %% [markdown]
# transparent with multiple tags
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png" alt="d" width="10"></img>

# %% [markdown]
# ![The image shows a pie chart representing the grade calculations of students, with categories such as A+, B, C, D, and F. Additionally, there are donut charts for "Homework," "Quizzes," and "Participation." These charts provide visual representation of student performance across different aspects. (This is an alt-text generated by a language model)](graphIssues2.jpeg)
